# %% [markdown]
# ## загрузка данных

# %%
# Загрузка и превью данных aim-2025-orcs
from pathlib import Path
import json, os, subprocess, zipfile, shutil
import pandas as pd

comp = "aim-2025-orcs"
data_dir = Path("data") / comp
data_dir.mkdir(parents=True, exist_ok=True)

workspace_cfg = Path("kaggle.json")
home_cfg_dir = Path.home() / ".kaggle"
home_cfg = home_cfg_dir / "kaggle.json"
if workspace_cfg.exists():
    home_cfg_dir.mkdir(exist_ok=True)
    data = json.loads(workspace_cfg.read_text())
    home_cfg.write_text(json.dumps(data))
    try:
        os.chmod(home_cfg, 0o600)
    except Exception:
        pass
    os.environ["KAGGLE_USERNAME"] = data.get("username", "")
    os.environ["KAGGLE_KEY"] = data.get("key", "")
else:
    print("kaggle.json не найден рядом с ноутбуком — пропускаю установку cred")

zip_files = list(data_dir.glob("*.zip"))
extracted_exists = any(
    p.is_file() and p.suffix.lower() in {".csv", ".tsv", ".parquet", ".json", ".parq", ".pq"}
    for p in data_dir.iterdir()
)

def try_cli_download() -> bool:
    if shutil.which("kaggle") is None:
        print("kaggle CLI not found in PATH")
        return False
    res = subprocess.run(
        ["kaggle", "competitions", "download", "-c", comp, "-p", str(data_dir)],
        capture_output=True,
        text=True,
    )
    if res.returncode != 0:
        print("kaggle CLI failed:")
        if res.stdout:
            print(res.stdout)
        if res.stderr:
            print(res.stderr)
        return False
    return True

def api_download():
    try:
        from kaggle import api
    except ImportError:
        raise RuntimeError("Install kaggle: pip install kaggle")
    api.authenticate()
    api.competition_download_files(comp, path=str(data_dir), quiet=False)

def ensure_data():
    if extracted_exists:
        print(f"Found extracted files in {data_dir.resolve()}, skip download.")
        return
    if zip_files:
        for zip_path in zip_files:
            with zipfile.ZipFile(zip_path) as zf:
                zf.extractall(data_dir)
        print(f"Used existing zip files in {data_dir.resolve()} and extracted.")
        return
    used_cli = try_cli_download()
    if not used_cli:
        api_download()
    for zip_path in data_dir.glob("*.zip"):
        with zipfile.ZipFile(zip_path) as zf:
            zf.extractall(data_dir)
    print(f"Downloaded and extracted to {data_dir.resolve()}")

ensure_data()

files = sorted([*data_dir.glob("*.parquet"), *data_dir.glob("*.csv")])
if not files:
    available = sorted(p.name for p in data_dir.glob("*"))
    print(f"Файлы не найдены в {data_dir.resolve()}. Доступно: {available}")
else:
    def preview(path):
        print(f"--- {path.name} ---")
        if path.suffix.lower() == ".parquet":
            display(pd.read_parquet(path).head(3))
        else:
            display(pd.read_csv(path, nrows=3))

    targets = {"orcs": None, "empl": None}
    for p in files:
        name = p.name.lower()
        if "orc" in name and targets["orcs"] is None:
            targets["orcs"] = p
        if "empl" in name and targets["empl"] is None:
            targets["empl"] = p

    for key, path in targets.items():
        if path is None:
            print(f"Файл с '{key}' в имени не найден. Доступно: {[p.name for p in files]}")
            continue
        preview(path)
# Out:
# Found extracted files in C:\Users\vipde\Desktop\AIMasters25\data\aim-2025-orcs, skip download.
# --- orcs.parquet ---
#         name   surname fathername gender   birthdate           inn    passport
# 0  габ`узхун      геля   шщэиевич      м  1961-10-13  209526320016  9427048895
# 1     сигурд  клабунов  васиолвич      м  1971-04-08  462095945786  9940565631
# 2   влоидмир  субботин   иванович      м  1974-07-22  611477616027  3851497038
# --- employees.parquet ---
#       name       surname    fathername gender   birthdate           inn  \
# 0  жумавой  волоколамц*в  садагет оглы      м  1973-12-24  804926960301
# 1     мубн   невмятуллин       али,вич      м  1984-07-06  111068355926
# 2   ан,рей        карпоэ  вяч.славовеч      м  1962-03-28  617713534516
#
#      passport
# 0  7880355409
# 1  1411814346
# 2  3428889207

# %% [markdown]
# ### Алгоритм нормализации имён
# - все строки в нижний регистр, `ё→е`, `й→и`
# - явный мусор (`none`, `нет`, `нету`, `отсутствует`, `ноне`, пустые) очищается в `null`
# - дефис заменяется пробелом, части двойного имени обрабатываются отдельно
# - визуальные латинские омоглифы транслитерируются в кириллицу (`a→а`, `p→р`, `y→у`, `o→о`, `c→с`, `x→х`, `e→е` и т.д.)
# - всё остальное вне русского алфавита (кроме пробела) превращается в джокер `*`
# - если в строке нет букв или букв меньше, чем спецсимволов (`*`), значение очищается
# - итог: только кириллические буквы + пробелы + `*`, лишние пробелы схлопываются

# %%
import json
import pandas as pd
from pathlib import Path

classes = ["corrected", "untouched", "ambiguous", "empty", "no_match"]

report_dirs = {
    "employees": Path("reports/name/employees"),
    "orcs": Path("reports/name/orcs"),
}

# Частоты по каждому датасету
for label, report_dir in report_dirs.items():
    dist_path = report_dir / "class_distribution.json"
    if dist_path.exists():
        counts = json.loads(dist_path.read_text(encoding="utf-8"))
        print(f"\n=== class counts: {label} ===")
        display(pd.Series(counts, name="count"))
    else:
        print(f"Нет файла {dist_path}")

# Примеры: две таблицы рядом (employees vs orcs) для каждого класса
for cls in classes:
    emp_samples_path = report_dirs["employees"] / "class_samples.json"
    orc_samples_path = report_dirs["orcs"] / "class_samples.json"
    if not emp_samples_path.exists() or not orc_samples_path.exists():
        print(f"Пропущен класс {cls}: нет файлов samples")
        continue
    emp_samples = json.loads(emp_samples_path.read_text(encoding="utf-8")).get(cls, [])
    orc_samples = json.loads(orc_samples_path.read_text(encoding="utf-8")).get(cls, [])

    emp_df = pd.DataFrame(emp_samples).head(20).add_suffix("_employees")
    orc_df = pd.DataFrame(orc_samples).head(20).add_suffix("_orcs")
    side = pd.concat([
        emp_df.reset_index(drop=True),
        orc_df.reset_index(drop=True)
    ], axis=1)
    print(f"\nКласс: {cls} (employees vs orcs)")
    display(side)
# Out:
# === class counts: employees ===
# ambiguous    143349
# corrected    294718
# empty            84
# no_match     821101
# untouched    752507
# Name: count, dtype: int64
# === class counts: orcs ===
# ambiguous     1463
# corrected     4692
# empty            4
# no_match     36576
# untouched     4898
# Name: count, dtype: int64
# Класс: corrected (employees vs orcs)
#    normalized_name_employees name_corrected_employees  is_name_employees  \
# 0                       льга                    ольга               True
# 1                    ни*олаи                  николаи               True
# 2                      андри                   андреи               True
# 3                      еелна                    елена               True
# 4                        гор                     егор               True
# 5                     се*геи                   сергеи               True
# 6                  екатери*а                екатерина               True
# 7                    геориги                  георгии               True
# 8                     ви*тор                   виктор               True
# 9                      мория                    мария               True
# 10                   ноталья                  наталья               True
# 11                     елено                    елена               True
# 12                     мория                    мария               True
# 13                     клена                    елена               True
# 14                 екотерина                екатерина               True
# 15                    максвм                   максим               True
# 16                 владеслав                владислав               True
# 17                 алексанрд                александр               True
# 18                 алекаандр                александр               True
# 19                   волерии                  валерии               True
#
#    normalized_name_orcs name_corrected_orcs  is_name_orcs
# 0               никола*             николаи          True
# 1             консантин          константин          True
# 2             брон*слав           бронислав          True
# 3              лютослав            любослав          True
# 4                ркслан              руслан          True
# 5              явчеслав            вячеслав          True
# 6               валереи             валерии          True
# 7                 вадем               вадим          True
# 8              антаолии            анатолии          True
# 9                юстине               юстин          True
# 10                дадан               жадан          True
# 11               альбер             альберт          True
# 12              еннадии            геннадии          True
# 13             свтелана            светлана          True
# 14                 еена               елена          True
# 15               басиль              василь          True
# 16                 нино                нина          True
# 17                 еван                иван          True
# 18              никол*и             николаи          True
# 19                 елеа               елена          True
# Класс: untouched (employees vs orcs)
#    normalized_name_employees name_corrected_employees  is_name_employees  \
# 0                   владимир                 владимир               True
# 1                   анатолии                 анатолии               True
# 2                   светлана                 светлана               True
# 3                   светлана                 светлана               True
# 4                     сергеи                   сергеи               True
# 5                     михаил                   михаил               True
# 6                   геннадии                 геннадии               True
# 7                      роман                    роман               True
# 8                  александр                александр               True
# 9                      борис                    борис               True
# 10                      юлия                     юлия               True
# 11                      олег                     олег               True
# 12                    андреи                   андреи               True
# 13                    михаил                   михаил               True
# 14                     елена                    елена               True
# 15                     мария                    мария               True
# 16                     елена                    елена               True
# 17                 александр                александр               True
# 18                  григории                 григории               True
# 19                    михаил                   михаил               True
#
#    normalized_name_orcs name_corrected_orcs  is_name_orcs
# 0                 павел               павел          True
# 1                  анна                анна          True
# 2                  юрии                юрии          True
# 3               ярослав             ярослав          True
# 4                 мария               мария          True
# 5                руслан              руслан          True
# 6                 елена               елена          True
# 7              владимир            владимир          True
# 8                михаил              михаил          True
# 9                сергеи              сергеи          True
# 10              наталья             наталья          True
# 11             анатолии            анатолии          True
# 12                тимур               тимур          True
# 13             светлана            светлана          True
# 14             светлана            светлана          True
# 15              дмитрии             дмитрии          True
# 16                 олег                олег          True
# 17            александр           александр          True
# 18                 петр                петр          True
# 19              алексеи             алексеи          True
# Класс: ambiguous (employees vs orcs)
#    normalized_name_employees name_corrected_employees  is_name_employees  \
# 0                    евдокия                  евдокия              False
# 1                 александра               александра              False
# 2                    клавдия                  клавдия              False
# 3                 александра               александра              False
# 4                      олеся                    олеся              False
# 5                       маря                     маря              False
# 6                  валентина                валентина              False
# 7                       ивна                     ивна              False
# 8                   антонина                 антонина              False
# 9                      раиса                    раиса              False
# 10                  антонина                 антонина              False
# 11                   вадимир                  вадимир              False
# 12                     данил                    данил              False
# 13                      иина                     иина              False
# 14                 валентина                валентина              False
# 15                    данила                   данила              False
# 16                     мариа                    мариа              False
# 17                     магар                    магар              False
# 18                   дмитрио                  дмитрио              False
# 19                    марина                   марина              False
#
#    normalized_name_orcs name_corrected_orcs  is_name_orcs
# 0                   иян                 иян         False
# 1                 раиса               раиса         False
# 2                 асмат               асмат         False
# 3             валентина           валентина         False
# 4                марина              марина         False
# 5                 раиса               раиса         False
# 6                   ома                 ома         False
# 7                 демир               демир         False
# 8             валентина           валентина         False
# 9                 фаиса               фаиса         False
# 10                олеся               олеся         False
# 11                раиса               раиса         False
# 12              валерия             валерия         False
# 13               марина              марина         False
# 14                 алиа                алиа         False
# 15             антонина            антонина         False
# 16                 юлищ                юлищ         False
# 17               марина              марина         False
# 18              евдокия             евдокия         False
# 19                 онна                онна         False
# Класс: empty (employees vs orcs)
#    normalized_name_employees name_corrected_employees  is_name_employees  \
# 0                       None                                       False
# 1                       None                                       False
# 2                       None                                       False
# 3                       None                                       False
# 4                       None                                       False
# 5                       None                                       False
# 6                       None                                       False
# 7                       None                                       False
# 8                       None                                       False
# 9                       None                                       False
# 10                      None                                       False
# 11                      None                                       False
# 12                      None                                       False
# 13                      None                                       False
# 14                      None                                       False
# 15                      None                                       False
# 16                      None                                       False
# 17                      None                                       False
# 18                      None                                       False
# 19                      None                                       False
#
#    normalized_name_orcs name_corrected_orcs is_name_orcs
# 0                  None                            False
# 1                  None                            False
# 2                  None                            False
# 3                  None                            False
# 4                   NaN                 NaN          NaN
# 5                   NaN                 NaN          NaN
# 6                   NaN                 NaN          NaN
# 7                   NaN                 NaN          NaN
# 8                   NaN                 NaN          NaN
# 9                   NaN                 NaN          NaN
# 10                  NaN                 NaN          NaN
# 11                  NaN                 NaN          NaN
# 12                  NaN                 NaN          NaN
# 13                  NaN                 NaN          NaN
# 14                  NaN                 NaN          NaN
# 15                  NaN                 NaN          NaN
# 16                  NaN                 NaN          NaN
# 17                  NaN                 NaN          NaN
# 18                  NaN                 NaN          NaN
# 19                  NaN                 NaN          NaN
# Класс: no_match (employees vs orcs)
#    normalized_name_employees name_corrected_employees  is_name_employees  \
# 0                      ирина                    ирина              False
# 1                     еснеия                   еснеия              False
# 2                     оскана                   оскана              False
# 3                     тамара                   тамара              False
# 4                      ол*ся                    ол*ся              False
# 5                      ия*ла                    ия*ла              False
# 6                      лидия                    лидия              False
# 7                     любовь                   любовь              False
# 8                     люмила                   люмила              False
# 9                  дильмурот                дильмурот              False
# 10                   юикфлаи                  юикфлаи              False
# 11                   людмела                  людмела              False
# 12                   мээрбек                  мээрбек              False
# 13                     драья                    драья              False
# 14                    глцина                   глцина              False
# 15                    магния                   магния              False
# 16                    кронид                   кронид              False
# 17                   альвена                  альвена              False
# 18                     римма                    римма              False
# 19                шарипачмал               шарипачмал              False
#
#    normalized_name_orcs name_corrected_orcs  is_name_orcs
# 0                кувцри              кувцри         False
# 1                нурбеи              нурбеи         False
# 2              курбоншо            курбоншо         False
# 3               ди*бази             ди*бази         False
# 4                бриуто              бриуто         False
# 5               людмила             людмила         False
# 6                 ханис               ханис         False
# 7               цезарии             цезарии         False
# 8               кубоныч             кубоныч         False
# 9                  пот*                пот*         False
# 10             нурмурат            нурмурат         False
# 11            захритдин           захритдин         False
# 12                н*сон               н*сон         False
# 13            ануш*рвон           ануш*рвон         False
# 14             вароздаи            вароздаи         False
# 15               фаизим              фаизим         False
# 16              ахвер*и             ахвер*и         False
# 17             джавхари            джавхари         False
# 18                ирали               ирали         False
# 19            садиридин           садиридин         False

# %%
# Отчёт по фамилиям: классы и 20 примеров по каждому классу (employees vs orcs)
import json
import pandas as pd
from pathlib import Path

classes = ["corrected", "untouched", "ambiguous", "empty", "no_match"]
report_dirs = {
    "employees": Path("reports/surname/employees"),
    "orcs": Path("reports/surname/orcs"),
}

for label, report_dir in report_dirs.items():
    dist_path = report_dir / "class_distribution.json"
    if dist_path.exists():
        counts = json.loads(dist_path.read_text(encoding="utf-8"))
        print(f"\n=== surname class counts: {label} ===")
        display(pd.Series(counts, name="count"))
    else:
        print(f"Нет файла {dist_path}")

for cls in classes:
    emp_path = report_dirs["employees"] / "class_samples.json"
    orc_path = report_dirs["orcs"] / "class_samples.json"
    if not emp_path.exists() or not orc_path.exists():
        print(f"Пропущен класс {cls}: нет файлов samples")
        continue
    emp_samples = json.loads(emp_path.read_text(encoding="utf-8")).get(cls, [])
    orc_samples = json.loads(orc_path.read_text(encoding="utf-8")).get(cls, [])

    emp_df = pd.DataFrame(emp_samples).head(20).add_suffix("_employees")
    orc_df = pd.DataFrame(orc_samples).head(20).add_suffix("_orcs")
    side = pd.concat([
        emp_df.reset_index(drop=True),
        orc_df.reset_index(drop=True)
    ], axis=1)
    print(f"\nКласс фамилии: {cls} (employees vs orcs)")
    display(side)
# Out:
# === surname class counts: employees ===
# ambiguous    418095
# corrected    429428
# empty            37
# no_match     418458
# untouched    745741
# Name: count, dtype: int64
# === surname class counts: orcs ===
# ambiguous     9825
# corrected     9992
# no_match     19428
# untouched     8388
# Name: count, dtype: int64
# Класс фамилии: corrected (employees vs orcs)
#    normalized_surname_employees surname_corrected_employees  \
# 0                      плоунина                    полунина
# 1                       гобуния                     габуния
# 2                      матаскин                    матыскин
# 3                      бочакрев                    бочкарев
# 4                      улезкина                    слезкина
# 5                      вер*инин                    вершинин
# 6                      кор*лина                    корелина
# 7                       володен                     володин
# 8                       ха*ьзов                     хальзов
# 9                         куоеш                       кулеш
# 10                      молащук                     малащук
# 11                     поспехзв                    поспехов
# 12                       белоед                     белодед
# 13                     федорена                    федорина
# 14                    мовсесова                    мосесова
# 15                     сетпанов                    степанов
# 16                        сеорв                       серов
# 17                   самодлеова                  самоделова
# 18                     п*вликов                    павликов
# 19                     совушкин                    савушкин
#
#     is_surname_employees normalized_surname_orcs surname_corrected_orcs  \
# 0                   True                шопортов               шапортов
# 1                   True                   лязер                  лявер
# 2                   True               сукорцева              суконцева
# 3                   True                 мнушк*н                мнушкин
# 4                   True                лупенцов               лубенцов
# 5                   True             красовецкии            красовицкии
# 6                   True                мякушкен               мякушкин
# 7                   True              лозовецкая             лозовицкая
# 8                   True                   дауде                   дауд
# 9                   True                 паяница               паляница
# 10                  True               петровнен              петровнин
# 11                  True                к*чкаров               кучкаров
# 12                  True               стаскевчи              стаскевич
# 13                  True                   мотях                  мотюх
# 14                  True                качма*ов               качмазов
# 15                  True               кормщикво              кормщиков
# 16                  True            колеснич*нко           колесниченко
# 17                  True                  паниык                  паник
# 18                  True                цуприяов               цуприков
# 19                  True                   зюзни                  зюзин
#
#     is_surname_orcs
# 0              True
# 1              True
# 2              True
# 3              True
# 4              True
# 5              True
# 6              True
# 7              True
# 8              True
# 9              True
# 10             True
# 11             True
# 12             True
# 13             True
# 14             True
# 15             True
# 16             True
# 17             True
# 18             True
# 19             True
# Класс фамилии: untouched (employees vs orcs)
#    normalized_surname_employees surname_corrected_employees  \
# 0                       корнева                     корнева
# 1                      логачева                    логачева
# 2                         клева                       клева
# 3                       никонов                     никонов
# 4                      кремнева                    кремнева
# 5                       шунтова                     шунтова
# 6                       иванова                     иванова
# 7                        белова                      белова
# 8                       полькин                     полькин
# 9                        кисель                      кисель
# 10                     барышева                    барышева
# 11                          жук                         жук
# 12                    нестерова                   нестерова
# 13                       онучин                      онучин
# 14                      гагарин                     гагарин
# 15                    кушнерева                   кушнерева
# 16                     хабарова                    хабарова
# 17                     клименко                    клименко
# 18                   емельянова                  емельянова
# 19                      лебедев                     лебедев
#
#     is_surname_employees normalized_surname_orcs surname_corrected_orcs  \
# 0                   True                    цыба                   цыба
# 1                   True                френкель               френкель
# 2                   True                юренкова               юренкова
# 3                   True                 леонова                леонова
# 4                   True               полянскии              полянскии
# 5                   True              безноскова             безноскова
# 6                   True                   зудин                  зудин
# 7                   True                   сытых                  сытых
# 8                   True                  коргун                 коргун
# 9                   True               тревогина              тревогина
# 10                  True              голованова             голованова
# 11                  True                 каленик                каленик
# 12                  True                безлюдов               безлюдов
# 13                  True                  марьин                 марьин
# 14                  True                 еремкин                еремкин
# 15                  True              маистренко             маистренко
# 16                  True       кузнецов мандрыка      кузнецов мандрыка
# 17                  True                здоровец               здоровец
# 18                  True                глатенок               глатенок
# 19                  True                ступаков               ступаков
#
#     is_surname_orcs
# 0              True
# 1              True
# 2              True
# 3              True
# 4              True
# 5              True
# 6              True
# 7              True
# 8              True
# 9              True
# 10             True
# 11             True
# 12             True
# 13             True
# 14             True
# 15             True
# 16             True
# 17             True
# 18             True
# 19             True
# Класс фамилии: ambiguous (employees vs orcs)
#    normalized_surname_employees surname_corrected_employees  \
# 0                         огров                       огров
# 1                         броин                       броин
# 2                        бурово                      бурово
# 3                      ерченков                    ерченков
# 4                       бухтино                     бухтино
# 5                          улюк                        улюк
# 6                      маст*ков                    маст*ков
# 7                     хлопенова                   хлопенова
# 8                        журино                      журино
# 9                      смирново                    смирново
# 10                       тихоов                      тихоов
# 11                      горькоа                     горькоа
# 12                       ончева                      ончева
# 13                   соломатиан                  соломатиан
# 14                       зоицев                      зоицев
# 15                        восов                       восов
# 16                     курерова                    курерова
# 17                      шеелева                     шеелева
# 18                         илев                        илев
# 19                      моринич                     моринич
#
#     is_surname_employees normalized_surname_orcs surname_corrected_orcs  \
# 0                  False                гулаидин               гулаидин
# 1                  False                    суая                   суая
# 2                  False              зрадовскии             зрадовскии
# 3                  False                  естаев                 естаев
# 4                  False                 холунов                холунов
# 5                  False                   белва                  белва
# 6                  False                 мерзаев                мерзаев
# 7                  False                  коцыло                 коцыло
# 8                  False                   рузив                  рузив
# 9                  False                 шеффлер                шеффлер
# 10                 False                 баба*ов                баба*ов
# 11                 False              стреганова             стреганова
# 12                 False              рыбчевскии             рыбчевскии
# 13                 False                 холичев                холичев
# 14                 False                   танов                  танов
# 15                 False                  алепов                 алепов
# 16                 False                 котефев                котефев
# 17                 False                мхалевич               мхалевич
# 18                 False                метюхина               метюхина
# 19                 False                забураев               забураев
#
#     is_surname_orcs
# 0             False
# 1             False
# 2             False
# 3             False
# 4             False
# 5             False
# 6             False
# 7             False
# 8             False
# 9             False
# 10            False
# 11            False
# 12            False
# 13            False
# 14            False
# 15            False
# 16            False
# 17            False
# 18            False
# 19            False
# Класс фамилии: empty (employees vs orcs)
#    normalized_surname_employees surname_corrected_employees  \
# 0                          None
# 1                          None
# 2                          None
# 3                          None
# 4                          None
# 5                          None
# 6                          None
# 7                          None
# 8                          None
# 9                          None
# 10                         None
# 11                         None
# 12                         None
# 13                         None
# 14                         None
# 15                         None
# 16                         None
# 17                         None
# 18                         None
# 19                         None
#
#     is_surname_employees
# 0                  False
# 1                  False
# 2                  False
# 3                  False
# 4                  False
# 5                  False
# 6                  False
# 7                  False
# 8                  False
# 9                  False
# 10                 False
# 11                 False
# 12                 False
# 13                 False
# 14                 False
# 15                 False
# 16                 False
# 17                 False
# 18                 False
# 19                 False
# Класс фамилии: no_match (employees vs orcs)
#    normalized_surname_employees surname_corrected_employees  \
# 0                        чашкне                      чашкне
# 1                       корпало                     корпало
# 2                        скердо                      скердо
# 3                     каибх*нов                   каибх*нов
# 4                     торыхчиев                   торыхчиев
# 5                       тиллекв                     тиллекв
# 6                       авакиви                     авакиви
# 7                      па*дуков                    па*дуков
# 8                       могаево                     могаево
# 9                       якиш*в*                     якиш*в*
# 10                 пряни*никово                пряни*никово
# 11                     п*шамоав                    п*шамоав
# 12                     измолкин                    измолкин
# 13                    клипацева                   клипацева
# 14                      руходзе                     руходзе
# 15                      вляеова                     вляеова
# 16                       шаккум                      шаккум
# 17                   хоритоново                  хоритоново
# 18                   че*веренко                  че*веренко
# 19                   черепанвао                  черепанвао
#
#     is_surname_employees normalized_surname_orcs surname_corrected_orcs  \
# 0                  False            венженовскии           венженовскии
# 1                  False               борбуцк*я              борбуцк*я
# 2                  False              чернпяшуев             чернпяшуев
# 3                  False                левурддк               левурддк
# 4                  False               филашихни              филашихни
# 5                  False                боатырив               боатырив
# 6                  False                   жекал                  жекал
# 7                  False               чоговадзе              чоговадзе
# 8                  False                   цаиек                  цаиек
# 9                  False              приблудово             приблудово
# 10                 False                  дешовы                 дешовы
# 11                 False                мецеевич               мецеевич
# 12                 False                 махаорв                махаорв
# 13                 False                синтерев               синтерев
# 14                 False                  пос*ва                 пос*ва
# 15                 False             юживанширев            юживанширев
# 16                 False                стерпнев               стерпнев
# 17                 False                 св*стич                св*стич
# 18                 False                  кимгвщ                 кимгвщ
# 19                 False                 шурп*ев                шурп*ев
#
#     is_surname_orcs
# 0             False
# 1             False
# 2             False
# 3             False
# 4             False
# 5             False
# 6             False
# 7             False
# 8             False
# 9             False
# 10            False
# 11            False
# 12            False
# 13            False
# 14            False
# 15            False
# 16            False
# 17            False
# 18            False
# 19            False

# %%
# Отчёт по отчествам: классы и 20 примеров (employees vs orcs)
import json
import pandas as pd
from pathlib import Path

classes = ["corrected", "untouched", "ambiguous", "empty", "no_match"]
report_dirs = {
    "employees": Path("reports/patronymic/employees"),
    "orcs": Path("reports/patronymic/orcs"),
}

for label, report_dir in report_dirs.items():
    dist_path = report_dir / "class_distribution.json"
    if dist_path.exists():
        counts = json.loads(dist_path.read_text(encoding="utf-8"))
        print(f"\n=== patronymic class counts: {label} ===")
        display(pd.Series(counts, name="count"))
    else:
        print(f"Нет файла {dist_path}")

for cls in classes:
    emp_path = report_dirs["employees"] / "class_samples.json"
    orc_path = report_dirs["orcs"] / "class_samples.json"
    if not emp_path.exists() or not orc_path.exists():
        print(f"Пропущен класс {cls}: нет файлов samples")
        continue
    emp_samples = json.loads(emp_path.read_text(encoding="utf-8")).get(cls, [])
    orc_samples = json.loads(orc_path.read_text(encoding="utf-8")).get(cls, [])

    emp_df = pd.DataFrame(emp_samples).head(20).add_suffix("_employees")
    orc_df = pd.DataFrame(orc_samples).head(20).add_suffix("_orcs")
    side = pd.concat([
        emp_df.reset_index(drop=True),
        orc_df.reset_index(drop=True)
    ], axis=1)
    print(f"\nКласс отчества: {cls} (employees vs orcs)")
    display(side)
# Out:
# === patronymic class counts: employees ===
# ambiguous     64985
# corrected    737450
# empty          5179
# no_match     602557
# untouched    601588
# Name: count, dtype: int64
# === patronymic class counts: orcs ===
# ambiguous      827
# corrected     9579
# empty           59
# no_match     33778
# untouched     3390
# Name: count, dtype: int64
# Класс отчества: corrected (employees vs orcs)
#    normalized_patronymic_employees patronymic_corrected_employees  \
# 0                       ьметриевнэ                     ьметриевна
# 1                       васильевла                     васильевна
# 2                        джониевно                      джониевна
# 3                        ромонович                      романович
# 4                     влади*ировна                   владимировна
# 5                       миахиловна                     михаиловна
# 6                      нкиифорович                    никифорович
# 7                         евановна                       ивановна
# 8                      филим*нович                    филимонович
# 9                    алекасндрович                  александрович
# 10                   александ*овна                  александровна
# 11                      витальевна                     виталиевна
# 12                    вялеславович                   вячеславович
# 13                        ивоновна                       ивановна
# 14                   александродна                  александровна
# 15                       матаеевич                      матвеевич
# 16                      николоевна                     николаевна
# 17                      викторовн*                     викторовна
# 18                       анд*еевна                      андреевна
# 19                       михиловна                     михаиловна
#
#     is_patronymic_employees normalized_patronymic_orcs  \
# 0                      True                   ромаович
# 1                      True                    иваовна
# 2                      True                   сргеевна
# 3                      True                     тсегие
# 4                      True                  сергеев*а
# 5                      True                 михрилович
# 6                      True                 михаиловеа
# 7                      True                 леонидовно
# 8                      True                     ивновн
# 9                      True             авлексанщъивия
# 10                     True                  евиниевно
# 11                     True              ал*ксандрович
# 12                     True               фезули кызыр
# 13                     True         валерии валерьевич
# 14                     True                 альбероына
# 15                     True               влюдпмиыован
# 16                     True                 викторовно
# 17                     True              галактионовие
# 18                     True                ольбертовна
# 19                     True              александровнж
#
#    patronymic_corrected_orcs  is_patronymic_orcs
# 0                  романович                True
# 1                   ивановна                True
# 2                  сергеевна                True
# 3                     тсегич                True
# 4                  сергеевна                True
# 5                 михаилович                True
# 6                 михаиловна                True
# 7                 леонидовна                True
# 8                    ивновна                True
# 9             авлексанщъивич                True
# 10                 евиниевна                True
# 11             александрович                True
# 12             фезулич кызыр               False
# 13        валерии валериевич               False
# 14                альберовна                True
# 15              влюдпмиыовна                True
# 16                викторовна                True
# 17             галактионович                True
# 18               альбертовна                True
# 19             александровна                True
# Класс отчества: untouched (employees vs orcs)
#    normalized_patronymic_employees patronymic_corrected_employees  \
# 0                    олександрович                  олександрович
# 1                       дмитриевна                     дмитриевна
# 2                         петровна                       петровна
# 3                     владимировна                   владимировна
# 4                       алексеевна                     алексеевна
# 5                        сергеевич                      сергеевич
# 6                        ильинична                      ильинична
# 7                         ивановна                       ивановна
# 8                          юриевич                        юриевич
# 9                       дмитриевич                     дмитриевич
# 10                      георгиевна                     георгиевна
# 11                      михаилович                     михаилович
# 12                    вениаминовна                   вениаминовна
# 13                      алексеевна                     алексеевна
# 14                        иванович                       иванович
# 15                   александрович                  александрович
# 16                   александровна                  александровна
# 17                   александровна                  александровна
# 18                      михаиловна                     михаиловна
# 19                      степановна                     степановна
#
#     is_patronymic_employees normalized_patronymic_orcs  \
# 0                      True               валентиновна
# 1                      True                   петровна
# 2                      True              александровна
# 3                      True              александровна
# 4                      True                 леонидович
# 5                      True                 алексеевич
# 6                      True                ладимировна
# 7                      True                   иванович
# 8                      True                  андреевич
# 9                      True                 николаевич
# 10                     True                 дмитриевич
# 11                     True               владимировна
# 12                     True              олександровна
# 13                     True                 николаевич
# 14                     True               вениаминович
# 15                     True                 викторовна
# 16                     True                  сергеевна
# 17                     True               валентиновна
# 18                     True                 алексеевна
# 19                     True                 алексеевич
#
#    patronymic_corrected_orcs  is_patronymic_orcs
# 0               валентиновна                True
# 1                   петровна                True
# 2              александровна                True
# 3              александровна                True
# 4                 леонидович                True
# 5                 алексеевич                True
# 6                ладимировна                True
# 7                   иванович                True
# 8                  андреевич                True
# 9                 николаевич                True
# 10                дмитриевич                True
# 11              владимировна                True
# 12             олександровна                True
# 13                николаевич                True
# 14              вениаминович                True
# 15                викторовна                True
# 16                 сергеевна                True
# 17              валентиновна                True
# 18                алексеевна                True
# 19                алексеевич                True
# Класс отчества: ambiguous (employees vs orcs)
#    normalized_patronymic_employees patronymic_corrected_employees  \
# 0                       анатольеви                    анатоль*еви
# 1                       васильевич                     васильевич
# 2                       васильевна                     васильевна
# 3                       васильевич                     васильевич
# 4                       васильевна                     васильевна
# 5                          якобови                       якоб*ови
# 6                       виколаевна                     виколаевна
# 7                       васильевна                     васильевна
# 8                          ванович                        ванович
# 9                     влодимирович                   влодимирович
# 10                    рладимировна                   рладимировна
# 11                        ефемовна                       ефемовна
# 12                       векторови                     вектор*ови
# 13                       ансимовна                      ансимовна
# 14                      васильевна                     васильевна
# 15                      васильевна                     васильевна
# 16                    влодимировна                   влодимировна
# 17                      васильевич                     васильевич
# 18                      васильевна                     васильевна
# 19                    влодимирович                   влодимирович
#
#     is_patronymic_employees normalized_patronymic_orcs  \
# 0                     False               влодимировна
# 1                     False                   егоревич
# 2                     False                   осифович
# 3                     False               лександровна
# 4                     False                   зелемови
# 5                     False                темболатови
# 6                     False                 васильевна
# 7                     False                  васильеви
# 8                     False                  роиановна
# 9                     False                    а*аевич
# 10                    False                   андеевна
# 11                    False                вчеславовна
# 12                    False                  дмитривна
# 13                    False                   агамович
# 14                    False              саиомардонови
# 15                    False                абдулфатови
# 16                    False               влодимирович
# 17                    False                     хосови
# 18                    False                   ибатович
# 19                    False               владимировнч
#
#    patronymic_corrected_orcs  is_patronymic_orcs
# 0               влодимировна               False
# 1                   егоревич               False
# 2                   осифович               False
# 3               лександровна               False
# 4                  зелем*ови               False
# 5               темболат*ови               False
# 6                 васильевна               False
# 7                 василь*еви               False
# 8                  роиановна               False
# 9                    а*аевич               False
# 10                  андеевна               False
# 11               вчеславовна               False
# 12                 дмитривна               False
# 13                  агамович               False
# 14            саиомардон*ови               False
# 15              абдулфат*ови               False
# 16              влодимирович               False
# 17                   хос*ови               False
# 18                  ибатович               False
# 19              владимировнч               False
# Класс отчества: empty (employees vs orcs)
#    normalized_patronymic_employees patronymic_corrected_employees  \
# 0                             None
# 1                             None
# 2                             None
# 3                             None
# 4                             None
# 5                             None
# 6                             None
# 7                             None
# 8                             None
# 9                             None
# 10                            None
# 11                            None
# 12                            None
# 13                            None
# 14                            None
# 15                            None
# 16                            None
# 17                            None
# 18                            None
# 19                            None
#
#     is_patronymic_employees normalized_patronymic_orcs  \
# 0                     False                       None
# 1                     False                       None
# 2                     False                       None
# 3                     False                       None
# 4                     False                       None
# 5                     False                       None
# 6                     False                       None
# 7                     False                       None
# 8                     False                       None
# 9                     False                       None
# 10                    False                       None
# 11                    False                       None
# 12                    False                       None
# 13                    False                       None
# 14                    False                       None
# 15                    False                       None
# 16                    False                       None
# 17                    False                       None
# 18                    False                       None
# 19                    False                       None
#
#    patronymic_corrected_orcs  is_patronymic_orcs
# 0                                          False
# 1                                          False
# 2                                          False
# 3                                          False
# 4                                          False
# 5                                          False
# 6                                          False
# 7                                          False
# 8                                          False
# 9                                          False
# 10                                         False
# 11                                         False
# 12                                         False
# 13                                         False
# 14                                         False
# 15                                         False
# 16                                         False
# 17                                         False
# 18                                         False
# 19                                         False
# Класс отчества: no_match (employees vs orcs)
#    normalized_patronymic_employees patronymic_corrected_employees  \
# 0                         омриовна                       омриовна
# 1                       садмпровис                     садмпровис
# 2                         изанощнэ                       изанощнэ
# 3                       арамашовна                     арамашовна
# 4                         иъатоврл                       иъатоврл
# 5                    гасан агаевеч                  гасан агаевеч
# 6                      влаимиаовна                    влаимиаовна
# 7                    бобомуродовеч                  бобомуродовеч
# 8                       восил*евич                     восил*евич
# 9                      мутагаровна                    мутагаровна
# 10                       шагимовна                      шагимовна
# 11                      евгэньевич                     евгэньевич
# 12                    ахмарбегович                   ахмарбегович
# 13                     севастиевич                    севастиевич
# 14                       раши*ович                      раши*ович
# 15                    шахрихонович                   шахрихонович
# 16                        наибкызы                       наибкызы
# 17                   сариддула*вич                  сариддула*вич
# 18                      витольевна                     витольевна
# 19                      валерьвкна                     валерьвкна
#
#     is_patronymic_employees normalized_patronymic_orcs  \
# 0                     False              мохаммда як*б
# 1                     False                  саханович
# 2                     False                   затеовна
# 3                     False                   ондревна
# 4                     False               аломудинович
# 5                     False                   словоммр
# 6                     False                чумобеко*ич
# 7                     False                 гендрикоич
# 8                     False                 м*каилович
# 9                     False                 к*чичиевич
# 10                    False                   бочисввч
# 11                    False                  арангович
# 12                    False                 василльвна
# 13                    False                  ренал*вна
# 14                    False                  налык*вна
# 15                    False                       ч*он
# 16                    False               халанзятов*ч
# 17                    False                 рестемович
# 18                    False                 васильев*а
# 19                    False                   и*ыновна
#
#    patronymic_corrected_orcs  is_patronymic_orcs
# 0              мохаммда як*б               False
# 1                  саханович               False
# 2                   затеовна               False
# 3                   ондревна               False
# 4               аломудинович               False
# 5                   словоммр               False
# 6                чумобеко*ич               False
# 7                 гендрикоич               False
# 8                 м*каилович               False
# 9                 к*чичиевич               False
# 10                  бочисввч               False
# 11                 арангович               False
# 12                василльвна               False
# 13                 ренал*вна               False
# 14                 налык*вна               False
# 15                      ч*он               False
# 16              халанзятов*ч               False
# 17                рестемович               False
# 18                васильев*а               False
# 19                  и*ыновна               False

# %% [markdown]
# # Анализ числовых значений

# %% [markdown]
# ## Дата рождения
# интересные особености:
# Employees (2 011 759 строк)
# ≥1 пропуск компонента: 6.99%; ≥2 пропуска: 6.99%; пустые ячейки: 6.99%.
# годов ~98.70% начинаются с 19
#
#
# Orcs (47 633 строк)
# ≥1 пропуск компонента: 9.03%; ≥2 пропуска: 9.03%; пустые ячейки: 9.03%.
# Чистые ISO: 90.48%.
#
# остальные аномалии датасета несущественны или не были обнаружены

# %% [markdown]
# ## ИНН
# Employees (2 011 759 строк)
# Чистые 12 цифр: 76.75%.
# Пустые: 22.98%
#
# Orcs (47 633 строк)
# Чистые 12 цифр: 42.84%.
# Пустые: 57.01%.
#
# остальные аномалии датасета несущественны или не были обнаружены

# %% [markdown]
# ## Паспортные данные
# Employees (2 011 759 строк)
# Чистые 10 цифр: 82.80%.
# Пустые: 17.03%.
#
# Orcs (47 633 строк)
# Чистые 10 цифр: 86.62%.
# Пустые: 13.07%.
#
# остальные аномалии датасета несущественны или не были обнаружены

# %% [markdown]
# ## гендер
# пустых строк нет, заполнено все

# %% [markdown]
# ## Вариант A — гибридный поиск ближайших соседей
# - Объединяем скорректированные/нормализованные ФИО в поле `full_name_text` для текстового поиска.
# - Жёстко матчим по валидным `inn` и `passport` (score=1.0), но не исключаем их из последующей проверки.
# - Для остальных строим TF-IDF по триграммам (`char`, 3-grams, `max_features=50000`, `min_df=2`) на `employees`, индексируем через `NearestNeighbors` (`cosine`, CSR).
# - Ищем для каждого `orc` топ-10 кандидатов батчами; пары пересчитываем с Levenshtein, датой рождения (бонус/штраф) и штрафом за несовпадение пола.
# - Итоговый `total_score`: взвешенная сумма text/name + корректировки даты/пола; оставляем кандидатов выше порога и сохраняем `submission.parquet`.
# - В конце выводим 10 случайных орков и по 3 наиболее релевантных кандидата для ручной проверки.

# %%
# Вариант A: гибридный поиск ближайших соседей (орки vs сотрудники)
from pathlib import Path
from datetime import datetime
import re
import numpy as np
import pandas as pd
from tqdm import tqdm
from IPython.display import display
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.neighbors import NearestNeighbors

# Настройки путей
EMP_PATH = Path("finaldata/employees_final.parquet")
ORC_PATH = Path("finaldata/orcs_final.parquet")
RESULTS_DIR = Path("results")
RESULTS_DIR.mkdir(parents=True, exist_ok=True)
RUN_ID = datetime.now().strftime("variantA_%Y%m%d_%H%M%S")
OUTPUT_DIR = RESULTS_DIR / RUN_ID
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
SUBMISSION_PATH = OUTPUT_DIR / "submission.parquet"
SUBMISSION_DETAILED_PATH = OUTPUT_DIR / "submission_detailed.parquet"

# -----------------------
# Утилиты
# -----------------------
try:
    from rapidfuzz.distance import Levenshtein as LevDist

    def name_similarity(a: str, b: str) -> float:
        return float(LevDist.normalized_similarity(a or "", b or "") / 100.0)
except Exception:
    import difflib

    def name_similarity(a: str, b: str) -> float:
        return difflib.SequenceMatcher(None, a or "", b or "").ratio()


def date_score(d1, d2) -> float:
    if pd.isna(d1) or pd.isna(d2):
        return 0.0
    return 0.2 if d1 == d2 else -0.5


def gender_penalty(g1: str, g2: str) -> float:
    if not g1 or not g2:
        return 0.0
    return -0.3 if g1 != g2 else 0.0


def safe_read_parquet(path: Path) -> pd.DataFrame:
    try:
        df = pd.read_parquet(path)
    except Exception as exc:
        raise RuntimeError(f"Не удалось прочитать {path}: {exc}") from exc
    df = df.reset_index(drop=True)
    df["orig_index"] = df.index
    return df


def first_nonnull(df: pd.DataFrame, cols: list[str]) -> pd.Series:
    available = [c for c in cols if c in df.columns]
    if not available:
        return pd.Series("", index=df.index)
    stacked = df[available].fillna("").astype(str)
    return stacked.bfill(axis=1).iloc[:, 0].fillna("")


def build_full_name(df: pd.DataFrame) -> pd.Series:
    surname_best = first_nonnull(df, ["surname_corrected", "surname_normalized", "surname"])
    name_best = first_nonnull(df, ["name_corrected", "name_normalized", "name"])
    patronymic_best = first_nonnull(df, ["patronymic_corrected", "patronymic_normalized", "fathername"])
    full = (surname_best + " " + name_best + " " + patronymic_best).str.replace(r"\s+", " ", regex=True).str.strip()
    return full


def clean_numeric(series: pd.Series, pattern: str) -> pd.Series:
    s = series.fillna("").astype(str).str.strip()
    return s.where(s.str.fullmatch(pattern))


def exact_matches(orcs_df: pd.DataFrame, emp_df: pd.DataFrame, key: str, label: str) -> pd.DataFrame:
    left = orcs_df[["orig_index", key, "full_name_text", "birthdate_dt", "gender_norm"]].rename(columns={"orig_index": "orc_idx"})
    right = emp_df[["orig_index", key, "full_name_text", "birthdate_dt", "gender_norm"]].rename(columns={"orig_index": "emp_idx"})
    left = left[left[key].notna() & (left[key] != "")]
    right = right[right[key].notna() & (right[key] != "")]
    merged = left.merge(right, on=key, how="inner", suffixes=("_orc", "_emp"))
    if merged.empty:
        return pd.DataFrame(columns=["orc_idx", "emp_idx", "match_type", "vector_sim", "name_sim", "date_score", "gender_penalty", "total_score"])
    merged["vector_sim"] = 1.0
    merged["name_sim"] = merged.apply(lambda r: name_similarity(r["full_name_text_orc"], r["full_name_text_emp"]), axis=1)
    merged["date_score"] = merged.apply(lambda r: date_score(r["birthdate_dt_orc"], r["birthdate_dt_emp"]), axis=1)
    merged["gender_penalty"] = merged.apply(lambda r: gender_penalty(r["gender_norm_orc"], r["gender_norm_emp"]), axis=1)
    merged["total_score"] = merged.apply(
        lambda r: max(1.0, 0.75 * r["name_sim"] + 0.25 * r["vector_sim"] + r["date_score"] + r["gender_penalty"]),
        axis=1,
    )
    merged["match_type"] = label
    return merged[["orc_idx", "emp_idx", "match_type", "vector_sim", "name_sim", "date_score", "gender_penalty", "total_score"]]


# -----------------------
# 1. Загрузка и подготовка
# -----------------------
print("Чтение данных...")
print(f"Результаты будут сохранены в: {OUTPUT_DIR.resolve()}")
employees = safe_read_parquet(EMP_PATH)
orcs = safe_read_parquet(ORC_PATH)

# Основное текстовое поле
employees["full_name_text"] = build_full_name(employees)
orcs["full_name_text"] = build_full_name(orcs)

# Даты/гендер/документы
employees["birthdate_dt"] = pd.to_datetime(employees["birthdate"], errors="coerce")
orcs["birthdate_dt"] = pd.to_datetime(orcs["birthdate"], errors="coerce")
employees["gender_norm"] = employees["gender"].fillna("").str.lower()
orcs["gender_norm"] = orcs["gender"].fillna("").str.lower()

employees["inn_clean"] = clean_numeric(employees["inn"], r"\d{12}")
orcs["inn_clean"] = clean_numeric(orcs["inn"], r"\d{12}")
employees["passport_clean"] = clean_numeric(employees["passport"], r"\d{10}")
orcs["passport_clean"] = clean_numeric(orcs["passport"], r"\d{10}")

print(f"employees: {len(employees):,} rows | orcs: {len(orcs):,} rows")

# -----------------------
# 2. Hard match по ИНН/паспортам
# -----------------------
print("Поиск строгих совпадений по ИНН и паспорту...")
inn_matches = exact_matches(orcs.assign(inn=orcs["inn_clean"]), employees.assign(inn=employees["inn_clean"]), "inn", "hard_inn")
pass_matches = exact_matches(orcs.assign(passport=orcs["passport_clean"]), employees.assign(passport=employees["passport_clean"]), "passport", "hard_passport")
print(f"Найдено hard-match по ИНН: {len(inn_matches):,}; по паспорту: {len(pass_matches):,}")

# -----------------------
# 3. Vector search (TF-IDF + kNN)
# -----------------------
print("Обучаем TF-IDF (char 3-gram)...")
# Ограничиваем число фич ради памяти
vectorizer = TfidfVectorizer(analyzer="char", ngram_range=(3, 3), min_df=2, max_features=30000, dtype=np.float32)
emp_matrix = vectorizer.fit_transform(employees["full_name_text"].fillna(""))
orc_matrix = vectorizer.transform(orcs["full_name_text"].fillna(""))

print("Строим индекс ближайших соседей...")
knn = NearestNeighbors(metric="cosine", algorithm="brute", n_neighbors=10, n_jobs=1)
knn.fit(emp_matrix)

batch_size = 1000  # уменьшили батч для экономии RAM
rows = []
print("Ищем кандидатов батчами...")
for start in tqdm(range(0, orc_matrix.shape[0], batch_size), desc="kNN batches"):
    end = min(start + batch_size, orc_matrix.shape[0])
    dist, idx = knn.kneighbors(orc_matrix[start:end], return_distance=True)
    for i in range(dist.shape[0]):
        orc_idx = start + i
        for d, emp_idx in zip(dist[i], idx[i]):
            rows.append((orc_idx, int(emp_idx), float(1.0 - d)))  # 1 - cosine distance = similarity

cand_df = pd.DataFrame(rows, columns=["orc_idx", "emp_idx", "vector_sim"])
print(f"Всего кандидатных пар из векторайзера: {len(cand_df):,}")

# -----------------------
# 4. Re-ranking: Levenshtein + дата + гендер
# -----------------------
orc_names = orcs["full_name_text"].fillna("").tolist()
emp_names = employees["full_name_text"].fillna("").tolist()
orc_dates = orcs["birthdate_dt"].tolist()
emp_dates = employees["birthdate_dt"].tolist()
orc_gender = orcs["gender_norm"].tolist()
emp_gender = employees["gender_norm"].tolist()

name_sims, date_scores, gender_penalties = [], [], []
for o_idx, e_idx in tqdm(zip(cand_df["orc_idx"].to_numpy(), cand_df["emp_idx"].to_numpy()), total=len(cand_df), desc="Re-ranking"):
    name_sims.append(name_similarity(orc_names[o_idx], emp_names[e_idx]))
    date_scores.append(date_score(orc_dates[o_idx], emp_dates[e_idx]))
    gender_penalties.append(gender_penalty(orc_gender[o_idx], emp_gender[e_idx]))

cand_df["name_sim"] = name_sims
cand_df["date_score"] = date_scores
cand_df["gender_penalty"] = gender_penalties
cand_df["match_type"] = "vector_topk"
cand_df["total_score"] = 0.75 * cand_df["name_sim"] + 0.25 * cand_df["vector_sim"] + cand_df["date_score"] + cand_df["gender_penalty"]

# -----------------------
# 5. Финальный отбор и сохранение
# -----------------------
all_pairs = pd.concat([cand_df, inn_matches, pass_matches], ignore_index=True)
all_pairs = all_pairs.sort_values("total_score", ascending=False).drop_duplicates(subset=["orc_idx", "emp_idx"], keep="first")
threshold = 0.8
final_pairs = all_pairs[all_pairs["total_score"] >= threshold].copy()

# Kaggle submission формат: [id, orig_index]; orig_index = emp_idx
submission_df = final_pairs.sort_values("total_score", ascending=False).drop_duplicates(subset=["emp_idx"]).copy()
submission_df = submission_df.rename(columns={"emp_idx": "orig_index"})
submission_df = submission_df[["orig_index"]]
submission_df.insert(0, "id", range(len(submission_df)))
submission_df.to_parquet(SUBMISSION_PATH, index=False)
print(f"Финальных кандидатов: {len(final_pairs):,}; submission rows: {len(submission_df):,}; сохранено в {SUBMISSION_PATH.resolve()}")
print("Формат submission (head):")
print(submission_df.head())

# -----------------------
# 6. Превью: 10 случайных орков и по 3 лучших кандидата
# -----------------------

rng = np.random.default_rng(42)
sample_orcs = rng.choice(orcs.index, size=min(10, len(orcs)), replace=False)
preview_rows = []
for o_idx in sample_orcs:
    top = final_pairs[final_pairs["orc_idx"] == o_idx].head(3)
    if top.empty:
        preview_rows.append(
            {
                "orc_idx": int(o_idx),
                "orc_name": orcs.loc[o_idx, "full_name_text"],
                "candidate_emp_idx": None,
                "candidate_emp_name": None,
                "total_score": None,
                "match_type": "no_candidates",
            }
        )
        continue
    for _, row in top.iterrows():
        preview_rows.append(
            {
                "orc_idx": int(o_idx),
                "orc_name": orcs.loc[o_idx, "full_name_text"],
                "candidate_emp_idx": int(row["emp_idx"]),
                "candidate_emp_name": employees.loc[int(row["emp_idx"]), "full_name_text"],
                "total_score": round(float(row["total_score"]), 4),
                "match_type": row["match_type"],
            }
        )

preview_df = pd.DataFrame(preview_rows)
print("\nПревью 10 случайных орков (по 3 кандидата):")
display(preview_df)

# Дополнительно сохраним расширенную таблицу (с именами и датами) при желании
final_with_names = final_pairs.copy()
final_with_names["orc_name"] = final_with_names["orc_idx"].map(lambda i: orcs.loc[i, "full_name_text"])
final_with_names["emp_name"] = final_with_names["emp_idx"].map(lambda i: employees.loc[i, "full_name_text"])
final_with_names.to_parquet(SUBMISSION_DETAILED_PATH, index=False)
print(f"Сохранён подробный вариант: {SUBMISSION_DETAILED_PATH}")
# Out:
# Чтение данных...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 105
#     102 orcs = safe_read_parquet(ORC_PATH)
#     104 # Основное текстовое поле
# --> 105 employees["full_name_text"] = build_full_name(employees)
#     106 orcs["full_name_text"] = build_full_name(orcs)
#     108 # Даты/гендер/документы
#
# Cell In[3], line 66, in build_full_name(df)
#      64 def build_full_name(df: pd.DataFrame) -> pd.Series:
#      65     surname_best = first_nonnull(df, ["surname_corrected", "surname_normalized", "surname"])
# ---> 66     name_best = first_nonnull(df, ["name_corrected", "name_normalized", "name"])
#      67     patronymic_best = first_nonnull(df, ["patronymic_corrected", "patronymic_normalized", "fathername"])
#      68     full = (surname_best + " " + name_best + " " + patronymic_best).str.replace(r"\s+", " ", regex=True).str.strip()
#
# Cell In[3], line 61, in first_nonnull(df, cols)
#      59     return pd.Series("", index=df.index)
#      60 stacked = df[available].fillna("").astype(str)
# ---> 61 return stacked.bfill(axis=1).iloc[:, 0].fillna("")
#
# File c:\Users\vipde\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:7825, in NDFrame.bfill(self, axis, inplace, limit, limit_area, downcast)
#    7818         if ctr <= ref_count:
#    7819             warnings.warn(
#    7820                 _chained_assignment_warning_method_msg,
#    7821                 FutureWarning,
#    7822                 stacklevel=2,
#    7823             )
# -> 7825 return self._pad_or_backfill(
#    7826     "bfill",
#    7827     axis=axis,
#    7828     inplace=inplace,
#    7829     limit=limit,
#    7830     limit_area=limit_area,
#    7831     # error: Argument "downcast" to "_fillna_with_method" of "NDFrame"
#    7832     # has incompatible type "Union[Dict[Any, Any], None,
#    7833     # Literal[_NoDefault.no_default]]"; expected "Optional[Dict[Any, Any]]"
#    7834     downcast=downcast,  # type: ignore[arg-type]
#    7835 )
#
# File c:\Users\vipde\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:7111, in NDFrame._pad_or_backfill(self, method, axis, inplace, limit, limit_area, downcast)
#    7105     result = self.T._pad_or_backfill(
#    7106         method=method, limit=limit, limit_area=limit_area
#    7107     ).T
#    7109     return result
# -> 7111 new_mgr = self._mgr.pad_or_backfill(
#    7112     method=method,
#    7113     axis=self._get_block_manager_axis(axis),
#    7114     limit=limit,
#    7115     limit_area=limit_area,
#    7116     inplace=inplace,
#    7117     downcast=downcast,
#    7118 )
#    7119 result = self._constructor_from_mgr(new_mgr, axes=new_mgr.axes)
#    7120 if inplace:
#
# File c:\Users\vipde\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\base.py:300, in DataManager.pad_or_backfill(self, inplace, **kwargs)
#     299 def pad_or_backfill(self, inplace: bool, **kwargs) -> Self:
# --> 300     return self.apply_with_block(
#     301         "pad_or_backfill",
#     302         inplace=inplace,
#     303         **kwargs,
#     304         using_cow=using_copy_on_write(),
#     305         already_warned=_AlreadyWarned(),
#     306     )
#
# File c:\Users\vipde\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\managers.py:363, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     361         applied = b.apply(f, **kwargs)
#     362     else:
# --> 363         applied = getattr(b, f)(**kwargs)
#     364     result_blocks = extend_blocks(applied, result_blocks)
#     366 out = type(self).from_blocks(result_blocks, self.axes)
#
# File c:\Users\vipde\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\blocks.py:1797, in Block.pad_or_backfill(self, method, axis, inplace, limit, limit_area, downcast, using_cow, already_warned)
#    1795 if axis == 1:
#    1796     vals = vals.T
# -> 1797 new_values = vals._pad_or_backfill(
#    1798     method=method,
#    1799     limit=limit,
#    1800     limit_area=limit_area,
#    1801     copy=copy,
#    1802 )
#    1803 if (
#    1804     not copy
#    1805     and warn_copy_on_write()
#    1806     and already_warned is not None
#    1807     and not already_warned.warned_already
#    1808 ):
#    1809     if self.refs.has_reference():
#
# File c:\Users\vipde\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\arrays\numpy_.py:273, in NumpyExtensionArray._pad_or_backfill(self, method, limit, limit_area, copy)
#     270     out_data = self._ndarray
#     272 meth = missing.clean_fill_method(method)
# --> 273 missing.pad_or_backfill_inplace(
#     274     out_data.T,
#     275     method=meth,
#     276     axis=0,
#     277     limit=limit,
#     278     limit_area=limit_area,
#     279 )
#     281 if not copy:
#     282     return self
#
# File c:\Users\vipde\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\missing.py:899, in pad_or_backfill_inplace(values, method, axis, limit, limit_area)
#     897 func = get_fill_func(method, ndim=2)
#     898 # _pad_2d and _backfill_2d both modify tvalues inplace
# --> 899 func(tvalues, limit=limit, limit_area=limit_area)
#
# File c:\Users\vipde\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\missing.py:935, in _datetimelike_compat.<locals>.new_func(values, limit, limit_area, mask)
#     930     result, mask = func(
#     931         values.view("i8"), limit=limit, limit_area=limit_area, mask=mask
#     932     )
#     933     return result.view(values.dtype), mask
# --> 935 return func(values, limit=limit, limit_area=limit_area, mask=mask)
#
# File c:\Users\vipde\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\missing.py:999, in _backfill_2d(values, limit, limit_area, mask)
#     996     _fill_limit_area_2d(mask, limit_area)
#     998 if values.size:
# --> 999     algos.backfill_2d_inplace(values, mask, limit=limit)
#    1000 else:
#    1001     # for test coverage
#    1002     pass
#
# KeyboardInterrupt:

# %% [markdown]
# ## Отчёт: 10 случайных примеров (3 кандидата на орка)
# Ниже для быстрой валидации выводится 10 случайных орков и до трёх лучших кандидатов из сотрудников (по `total_score`). Использует результаты последнего запуска (берёт из памяти, иначе из `submission_detailed.parquet`).

# %%
# Если pipeline уже выполнен — используем final_pairs/orcs/employees из памяти.
# Иначе пробуем загрузить submission_detailed.parquet.
from pathlib import Path
import numpy as np
import pandas as pd

rng = np.random.default_rng(123)

if "final_pairs" in globals() and "orcs" in globals() and "employees" in globals():
    source_df = final_pairs.copy()
    source_df["orc_name"] = source_df["orc_idx"].map(lambda i: orcs.loc[i, "full_name_text"])
    source_df["emp_name"] = source_df["emp_idx"].map(lambda i: employees.loc[i, "full_name_text"])
    print("Используем результаты из памяти (после последнего запуска pipeline)")
elif Path("submission_detailed.parquet").exists():
    source_df = pd.read_parquet("submission_detailed.parquet")
    print("Используем сохранённый submission_detailed.parquet")
else:
    raise RuntimeError("Нет данных для отчёта: выполните pipeline или положите submission_detailed.parquet")

unique_orcs = source_df["orc_idx"].drop_duplicates().to_numpy()
sample_orcs = rng.choice(unique_orcs, size=min(10, len(unique_orcs)), replace=False)

rows = []
for o_idx in sample_orcs:
    top = source_df[source_df["orc_idx"] == o_idx].sort_values("total_score", ascending=False).head(3)
    if top.empty:
        rows.append({"orc_idx": int(o_idx), "orc_name": None, "candidate_emp_idx": None, "candidate_emp_name": None, "total_score": None, "match_type": "no_candidates"})
        continue
    for _, r in top.iterrows():
        rows.append(
            {
                "orc_idx": int(o_idx),
                "orc_name": r.get("orc_name"),
                "candidate_emp_idx": int(r["emp_idx"]),
                "candidate_emp_name": r.get("emp_name"),
                "total_score": round(float(r["total_score"]), 4),
                "match_type": r.get("match_type", "vector_topk"),
            }
        )

report_df = pd.DataFrame(rows)
print("10 случайных орков и топ-3 кандидатов:")
display(report_df)
# Out:
# Используем результаты из памяти (после последнего запуска pipeline)
# 10 случайных орков и топ-3 кандидатов:
#    orc_idx                       orc_name  candidate_emp_idx  \
# 0    46921      егорова лилия онатольевна            1860716
# 1    39936    панькина шалентина ивановна            1635547
# 2    39011     цыганкова елена николаевна             569520
# 3    34303      стебо ваентинн хуидодов*ч            1432641
# 4    19879   ершова татьяна алдкяандровна             304313
# 5    24436  золотько константин сергеевич             732379
# 6    37506      севрюокво нина василиевна              30623
# 7     7089      кацгина галина виталиевна            1430857
# 8    40461         регер наиля измои*овна             516633
# 9    45480    морщагио альберт германович             252181
#
#               candidate_emp_name  total_score     match_type
# 0        егорова лилия аатолевна          1.0  hard_passport
# 1     панькина валентина вановна          1.0       hard_inn
# 2     цыганкова елена николаевна          1.0  hard_passport
# 3     стегно валентин хуидодови*          1.0  hard_passport
# 4   ершова татьяна олександровна          1.0  hard_passport
# 5  золотько константин сергеевич          1.0  hard_passport
# 6      севрюкова нина васильевна          1.0  hard_passport
# 7     кла*гина голина виталиевна          1.0       hard_inn
# 8         регвг ноиля измаиловна          1.0  hard_passport
# 9    морщакин эльберь германович          1.0  hard_passport
# Отчёт сохранён: results\preview_orcs_candidates.parquet

# %%
# Превью: 10 случайных орков и топ-3 кандидата из последнего прогноза
from pathlib import Path
import pandas as pd

results_dirs = sorted(Path("results").glob("splink_results_*"))
if not results_dirs:
    raise FileNotFoundError("Нет результатов в каталоге results/")

latest_dir = results_dirs[-1]
pred_path = latest_dir / "suspected_orcs.csv"
print(f"Используем предсказания: {pred_path}")

pred = pd.read_csv(pred_path)
if pred.empty:
    display(pd.DataFrame({"info": ["Файл предсказаний пуст"]}))
else:
    orcs = (
        pd.read_parquet(
            "finaldata/orcs_final.parquet",
            columns=["name", "surname", "fathername", "birthdate"],
        )
        .reset_index()
        .rename(columns={"index": "orc_id"})
    )
    employees = (
        pd.read_parquet(
            "finaldata/employees_final.parquet",
            columns=["name", "surname", "fathername"],
        )
        .reset_index()
        .rename(columns={"index": "employee_id"})
    )

    orcs["orc_full_name"] = (
        orcs[["surname", "name", "fathername"]]
        .fillna("")
        .agg(" ".join, axis=1)
        .str.replace(r"\s+", " ", regex=True)
        .str.strip()
    )
    employees["employee_full_name"] = (
        employees[["surname", "name", "fathername"]]
        .fillna("")
        .agg(" ".join, axis=1)
        .str.replace(r"\s+", " ", regex=True)
        .str.strip()
    )

    top3 = (
        pred.sort_values("match_probability", ascending=False)
        .groupby("orc_id")
        .head(3)
    )

    if top3.empty:
        display(pd.DataFrame({"info": ["Нет кандидатов после порога"]}))
    else:
        sample_orcs = top3["orc_id"].drop_duplicates().sample(
            n=min(10, top3["orc_id"].nunique()), random_state=42
        )
        preview = (
            top3[top3["orc_id"].isin(sample_orcs)]
            .merge(orcs[["orc_id", "orc_full_name", "birthdate"]], on="orc_id", how="left")
            .merge(
                employees[["employee_id", "employee_full_name"]],
                on="employee_id",
                how="left",
            )
            .sort_values(["orc_id", "match_probability"], ascending=[True, False])
        )

        display(
            preview[
                [
                    "orc_id",
                    "orc_full_name",
                    "birthdate",
                    "employee_id",
                    "employee_full_name",
                    "match_probability",
                ]
            ]
        )
# Out:
# Используем предсказания: results\splink_results_20251207_031124\suspected_orcs.csv
#                      info
# 0  Файл предсказаний пуст
